# %% [markdown]
# # Tugas 1

# %% [markdown]
# ## Data Integration

# %%
import pandas as pd
data1=pd.read_csv('datatugas1.csv')
data2=pd.read_csv('datatugas2.csv')

data=pd.merge(data1,data2,on='Author ID')
data
# Out:
#       Author ID                           fullname          NIDN  sinta_score  \
# 0   5.97256e+06                          DAMAYANTI  2.810601e+07        65.15
# 1   6.02947e+06             ENDANG SULISTYANINGSIH  2.710670e+07         8.29
# 2    5.9883e+06                           KUSWANTO  1.107630e+07         5.89
# 3   5.97541e+06                          SUPRIYADI  1.206610e+07         6.31
# 4   6.04319e+06    DR. SAPJA ANANTANYU, SP., M.SI.  2.712681e+07         4.31
# 5   6.03844e+06                    AZIZ PURWANTORO  5.086204e+06         8.83
# 6   5.98944e+06           MOCHAMMAD DAWAM MAGHFOER  1.407570e+07         6.12
# 7   5.98078e+06                     EFRI MARDAWATI  1.203780e+07         5.28
# 8   5.97561e+06                      DANNER SAGALA  4.108101e+06         3.08
# 9   6.09699e+06                     DIDIK HARIYONO  1.010562e+07         2.68
# 10  6.01091e+06                      DAIMON SYUKRI  2.606811e+07         5.45
# ...
